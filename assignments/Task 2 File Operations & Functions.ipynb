# %% [markdown]
# # Task 2:File Operations & Functions
#     make a function to do the
#         1-open the whole folder
#         2-create number of files inside it
#         3-check the len of files in that folder
#         4-delete random half of this folder
#         5-check the result

# %%
import os
import random

folder_path = "D:/AI"

def process_folder(folder_path, num_to_create):
    # 1. Check if folder exists
    if not os.path.isdir(folder_path):
        print(f"Error: Folder '{folder_path}' does not exist.")
        return

    # 2. Create files inside
    for i in range(num_to_create):
        file_path = os.path.join(folder_path, f"test_file_{i}.txt")
        with open(file_path, 'w') as f:
            f.write("Sample content")
    print(f"Created {num_to_create} files.")

    # 3. Check initial file count
    files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    print(f"Initial count: {len(files)}")

    # 4. Delete random half
    num_to_delete = len(files) // 2
    files_to_remove = random.sample(files, num_to_delete)
    
    for file_name in files_to_remove:
        os.remove(os.path.join(folder_path, file_name))
    print(f"Deleted {num_to_delete} random files.")

    # 5. Check final result
    remaining_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    print(f"Final count: {len(remaining_files)}")
    print("Files left:", remaining_files)

# Usage: Replace 'my_folder' with your actual folder name
if __name__ == "__main__":
    process_folder("my_folder", 10)
